# %% [markdown]
# <a href="https://colab.research.google.com/github/dabyong/FlyRank-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
# !git clone https://github.com/dabyong/FlyRank-internship.git

os.chdir("FlyRank-internship")

print("Dataset exists?", os.path.exists("data/raw/content_refresh_anonymized.csv"))
# Out:
# Cloning into 'FlyRank-internship'...
# remote: Enumerating objects: 115, done.
# remote: Counting objects: 100% (115/115), done.
# remote: Compressing objects: 100% (71/71), done.
# remote: Total 115 (delta 31), reused 96 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (115/115), 1.84 MiB | 8.19 MiB/s, done.
# Resolving deltas: 100% (31/31), done.
# Dataset exists? True

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/dabyong/FlyRank-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Lane: Content Refresh Prioritization / Content Decay
#
#
# Why this lane? > Websites lose substantial organic search traffic over time as competitors update articles or search intent shifts. Instead of manually guessing which articles need a rewrite, we need an automated prioritization system that flags truly decaying pages before traffic collapses. Early data exploration shows that simple metrics like raw search_volume fail to predict traffic , making a multi-signal machine learning ranking model essential for identifying high-impact refresh candidates.

# %%
# This cell is for CODE (numbers, a query, a check).
import pandas as pd
import os

# Adjust path if running inside work/notebooks/ directory
if not os.path.exists("data/raw/content_refresh_anonymized.csv") and os.path.exists("../../data/raw/content_refresh_anonymized.csv"):
    os.chdir("../..")

print("Current Working Directory:", os.getcwd())
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
# Current Working Directory: /content/FlyRank-internship/FlyRank-internship

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# * Decision: Which decaying content pieces should the editorial team refresh first this week?
# * Who acts on it? Content Operations managers, SEO Strategists, and Copywriters.
#
# Cost of a wrong call:
# * False Positive (refreshing a page that isn't declining): Wastes 4–8 hours of editorial time and writer budgets on content that didn't need work.
# * False Negative (missing a page in steep decline): Results in lost rankings to competitors, lower site-wide impressions, and lost revenue that becomes increasingly harder to recover over time.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# 1. Search Volume vs. Impressions: The correlation between search_volume and impressions_90d is 0.001 —even after confirming all 30,000 pages are active (impressions_90d > 0). High search volume does not guarantee traffic.
# 2. CTR Collapse: Mean Click-Through-Rate drops sharply from 78.7% on Page 1 (positions 1–10) to 22.2% on Pages 3–5 (positions 21–50). This non-linear drop proves why "striking distance" pages need urgent refresh models.
# 3. Word Count Misconception: Pages trending down have a median word count of 2,909, nearly identical to pages trending up (2,848). Content length is not the primary driver of freshness or rankings.

# %%
# This cell is for CODE (numbers, a query, a check).
import pandas as pd

# Load dataset
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# 1. Search Volume vs Impressions Correlation
corr = df['search_volume'].corr(df['impressions_90d'])
print(f"1. Search Volume vs Impressions Correlation: {corr:.3f}")

# 2. Average CTR by Position Group (multiply by 100 for percentage)
page_1_ctr = df[df['avg_position'] <= 10]['ctr'].mean() * 100
page_3_5_ctr = df[(df['avg_position'] > 20) & (df['avg_position'] <= 50)]['ctr'].mean() * 100
print(f"2. Page 1 CTR: {page_1_ctr:.1f}% | Page 3-5 CTR: {page_3_5_ctr:.1f}%")

# 3. Median Word Count by Trend Direction
declining_wc = df[df['trend_direction'] == 'down']['word_count'].median()
growing_wc = df[df['trend_direction'] == 'up']['word_count'].median()
print(f"3. Median Word Count — Declining: {declining_wc:.0f} | Growing: {growing_wc:.0f}")
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
# 1. Search Volume vs Impressions Correlation: 0.001
# 2. Page 1 CTR: 78.7% | Page 3-5 CTR: 22.2%
# 3. Median Word Count — Declining: 2909 | Growing: 2848

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# What I CAN claim:
# * Observed patterns: Observed non-linear relationships between ranking tiers and user engagement/CTR.
# * Directional prioritization: Models provide decision-support ranking that flags pages with a higher statistical probability of traffic decay compared to hand-coded heuristics.
# * Model superiority: ML models (like Random Forests) achieve significantly higher Precision@50 than single-feature baseline rules on holdout client evaluation.
#
# What I CANNOT claim:
# * I cannot claim causal proof (e.g., "adding 500 words causes a ranking jump").
# * I cannot claim to have "decoded Google's algorithm."
# * I cannot guarantee that refreshing a flagged page will always restore lost traffic.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
